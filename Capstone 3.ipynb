# %% [markdown]
# # **Saudi Arabia Used Cars**

# %% [markdown]
# # Contents
# - Business Problem Understanding
# - Data Understanding
# - Data Preprocessing
# - Modeling
# - Conclusion
# - Recommendation

# %% [markdown]
# ![DALL·E 2024-09-14 11.13.58 - The same wide image of used cars parked in a neat lot under a clear sky in Saudi Arabia, with desert landscapes and modern buildings in the background.webp](<attachment:DALL·E 2024-09-14 11.13.58 - The same wide image of used cars parked in a neat lot under a clear sky in Saudi Arabia, with desert landscapes and modern buildings in the background.webp>)

# %% [markdown]
# ## **Business Problem Understanding**

# %% [markdown]
# ### **Background**

# %% [markdown]
# Arab Saudi adalah negara terbesar di Timur Tengah dengan populasi sekitar **34 juta jiwa**, di mana **42% dari penduduknya merupakan warga negara asing**. Populasi warga asing yang signifikan ini meningkatkan kebutuhan akan berbagai barang dan jasa, termasuk kendaraan. Harga bahan bakar yang sangat murah di Arab Saudi, yang termasuk paling rendah di dunia, mendorong tingginya penggunaan mobil pribadi di negara tersebut.
#
# Dalam beberapa tahun terakhir, pasar mobil bekas di Arab Saudi terus tumbuh seiring dengan perubahan ekonomi dan preferensi konsumen. Banyak konsumen beralih ke mobil bekas sebagai pilihan yang lebih terjangkau dibandingkan membeli mobil baru. Faktor-faktor seperti kondisi keuangan yang berubah-ubah dan kebutuhan mobilitas sehari-hari juga menjadi pendorong utama peningkatan permintaan terhadap mobil bekas.
#
# Meskipun pasar mobil bekas berkembang, ia tetap dipengaruhi oleh fluktuasi harga berdasarkan merek, jenis transmisi, kapasitas mesin, jarak tempuh, dan tahun produksi. Ini membuat penentuan harga mobil bekas menjadi tantangan bagi penjual dan pembeli. Di tengah kondisi pasar yang tidak menentu ini, prediksi harga mobil bekas menjadi semakin penting untuk membantu dalam pengambilan keputusan yang tepat terkait jual-beli kendaraan.

# %% [markdown]
# ### **Stakeholders**

# %% [markdown]
# **Marketplace Platform**
#
# Sebagai penyedia layanan jual-beli mobil bekas, marketplace bertanggung jawab untuk menyediakan alat atau model prediksi harga yang akurat. Marketplace juga harus memastikan harga yang ditawarkan kompetitif dan sesuai dengan kondisi pasar untuk memaksimalkan transaksi dan keuntungan.

# %% [markdown]
# ### **Problem Statement**

# %% [markdown]
# Salah satu tantangan utama yang dihadapi **marketplace mobil bekas di Arab Saudi** adalah menetapkan **harga yang tepat** untuk mobil bekas, sehingga tidak terlalu tinggi yang dapat mengurangi minat konsumen, atau terlalu rendah yang bisa menyebabkan kerugian bagi penjual. Marketplace harus mempertimbangkan berbagai faktor, seperti **tipe mobil**, **jarak tempuh**, **jenis transmisi**, dan **fitur tambahan**, untuk mencapai **harga yang kompetitif dan optimal**. Dalam konteks **dataset ini** yang mencakup **5624 data mobil bekas**, terdapat informasi penting yang mempengaruhi **harga jual**. Oleh karena itu, diperlukan **metode atau model** yang dapat menghasilkan **estimasi harga yang akurat dan adil**, sehingga dapat membantu marketplace menentukan **harga yang transparan** dan sesuai dengan **kondisi pasar**.

# %% [markdown]
# ### **Goals**

# %% [markdown]
# Berdasarkan tantangan dalam penentuan **harga mobil bekas**, marketplace membutuhkan **alat atau model prediksi** yang dapat memproyeksikan **harga jual optimal** untuk mobil bekas. Alat ini akan membantu penjual dalam **menentukan harga yang tepat** dengan mempertimbangkan berbagai faktor seperti **jenis mobil**, **kondisi mesin**, **tahun produksi**, **jarak tempuh**, dan **opsi tambahan** lainnya. Dengan adanya **prediksi harga yang akurat**, diharapkan keputusan yang diambil oleh para pemangku kepentingan akan lebih mudah dan menguntungkan, baik dari segi **persaingan pasar** maupun **potensi keuntungan**. **Prediksi yang transparan dan adil** akan membantu meningkatkan **transaksi** dan **kepercayaan** antara penjual dan pembeli, serta mendorong **pertumbuhan bisnis** marketplace secara keseluruhan.

# %% [markdown]
# ### **Analytic Approach**

# %% [markdown]
# Permasalahan ini akan dianalisis dengan meninjau data untuk menemukan pola-pola fitur yang membedakan satu mobil bekas dari yang lain. Langkah awal dilakukan melalui eksplorasi data guna mengungkap perbedaan antara fitur-fitur seperti tipe mobil, jarak tempuh, jenis transmisi, dan opsi tambahan. Eksplorasi ini bertujuan memberikan wawasan mendalam mengenai faktor-faktor yang memengaruhi harga mobil bekas.
#
# Setelah pola-pola tersebut diidentifikasi, langkah berikutnya adalah merancang model regresi untuk memprediksi harga mobil bekas secara akurat. Model ini akan membantu marketplace menentukan harga yang kompetitif, mencegah terjadinya harga yang terlalu tinggi atau terlalu rendah. Dengan estimasi harga yang lebih tepat, diharapkan keputusan jual-beli dapat dilakukan secara lebih efisien dan menguntungkan bagi penjual maupun pembeli.

# %% [markdown]
# ### **Evaluation Metric**

# %% [markdown]
# Dalam pengembangan model **Machine Learning** ini, beberapa **metrik evaluasi** yang digunakan adalah sebagai berikut:
#
# - **RMSE (Root Mean Squared Error)**: Menghitung rata-rata akar kuadrat dari kesalahan prediksi.
# - **MAE (Mean Absolute Error)**: Mengukur rata-rata dari nilai absolut kesalahan prediksi.
# - **MAPE (Mean Absolute Percentage Error)**: Menghitung rata-rata persentase kesalahan yang dihasilkan oleh model regresi.
# - **R-Square (R²)**: Menunjukkan seberapa banyak variasi nilai **Y** yang dapat dijelaskan oleh model yang dibangun.
#
# Model akan semakin baik dalam memprediksi **harga mobil bekas** apabila nilai **R-Square** mendekati 1 dan nilai **RMSE**, **MAE**, serta **MAPE** semakin kecil. Dengan begitu, kesalahan prediksi bisa diminimalkan, dan akurasi model dalam menentukan harga mobil bekas dapat meningkat sesuai dengan keterbatasan fitur yang digunakan.

# %% [markdown]
# ## **Data Understanding**

# %% [markdown]
# ### **Importing Libraries and Dataset**

# %% [markdown]
# Dataset ini mewakili satu mobil bekas, memberikan detail seperti nama merek, model, tahun pembuatan, asal, opsi, kapasitas mesin, jenis transmisi, jarak tempuh, harga di wilayah tertentu, dan status negosiasi.
#
# `Dataset:`
#
# | No  | Kolom      | Deskripsi                                                                                     |
# | --- | ---------- | --------------------------------------------------------------------------------------------- |
# | 1   | `Type`       | Kategori dari mobil bekas yang dijual                                                                              |
# | 2   | `Region`     | Lokasi geografis tempat mobil tersebut dipasarkan                                                |
# | 3   | `Make`       | Pabrikan atau merek yang memproduksi kendaraan tersebut                                                         |
# | 4   | `Gear_Type`  | Tipe atau jenis transmisi mobil yang ditawarkan                                                                   |
# | 5   | `Origin`     | Asal mobil berdasarkan wilayah (Gulf / Saudi / Other)                                                        |
# | 6   | `Options`    | Fitur tambahan yang tersedia pada mobil (Pilihan Lengkap / Semi-Lengkap / Standar)                   |
# | 7   | `Year`       | Tahun produksi mobil tersebut                                                                          |
# | 8   | `Engine_Size`| Kapasitas atau ukuran mesin kendaraan                                                                             |
# | 9   | `Mileage`    | Jumlah jarak yang telah ditempuh oleh kendaraan (dalam kilometer)                                               |
# | 10  | `Negotiable` | Status harga bisa dinegosiasi (True/False), True berarti bisa dinegosiasi jika harga 0 |
# | 11  | `Price`      | Harga yang ditawarkan untuk kendaraan tersebut (dalam Riyal)                                                     |

# %%
#Modul Utama
import pandas as pd
import numpy as np

#Modul Visualisasi
import seaborn as sns
import matplotlib.pyplot as plt


#Modul untuk imputer
from sklearn.impute import SimpleImputer, KNNImputer


#Modul Preprocesiing
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, OneHotEncoder, OrdinalEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
import category_encoders as ce


#Modul split tuning parameter, & cross validasi
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold,GridSearchCV, RandomizedSearchCV, KFold

#Modul Machine Learning
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor, NearestNeighbors
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from catboost import CatBoostRegressor
from sklearn.neural_network import MLPRegressor
from sklearn import svm
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, ExtraTreesRegressor, RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.compose import TransformedTargetRegressor
import pickle
import dython
from dython.nominal import correlation_ratio
from xgboost import XGBRegressor

#modul metrics
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error,mean_absolute_percentage_error,root_mean_squared_error

#Modul Feature Selection
from sklearn.feature_selection import SelectPercentile, SelectKBest,f_regression, f_classif

#Modul untuk Pipeline
from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as ImbPipeline

#Modul untuk handling imbalance method
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler, NearMiss

#Modul untuk running time
import time

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### **Read the dataset**

# %%
# Load dataset
df = pd.read_csv('data_saudi_used_cars.csv')
df
# Out:
#              Type          Region        Make  Gear_Type       Origin  \
# 0         Corolla            Abha      Toyota     Manual        Saudi
# 1           Yukon          Riyadh         GMC  Automatic        Saudi
# 2     Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic
# 3          Optima  Hafar Al-Batin         Kia  Automatic        Saudi
# 4              FJ          Riyadh      Toyota  Automatic        Saudi
# ...           ...             ...         ...        ...          ...
# 5619      X-Trail          Jeddah      Nissan  Automatic        Saudi
# 5620       Altima          Jeddah      Nissan  Automatic        Saudi
# 5621        Yukon          Dammam         GMC  Automatic        Saudi
# 5622           RX          Dammam       Lexus  Automatic  Gulf Arabic
# 5623           ES          Jeddah       Lexus  Automatic        Other
#
#         Options  Year  Engine_Size  Mileage  Negotiable   Price
# ...

# %% [markdown]
# Pada awal kode, kita menampilkan informasi umum tentang dataset menggunakan `df.info()`. Hal ini memberikan gambaran tentang jumlah kolom, tipe data di setiap kolom, serta jumlah nilai non-null (nilai yang ada) di setiap kolom. Ini berguna untuk memahami jenis data yang ada sebelum melakukan analisis statistik.

# %%
#sekilas info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5624 entries, 0 to 5623
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Type         5624 non-null   object
#  1   Region       5624 non-null   object
#  2   Make         5624 non-null   object
#  3   Gear_Type    5624 non-null   object
#  4   Origin       5624 non-null   object
#  5   Options      5624 non-null   object
#  6   Year         5624 non-null   int64
#  7   Engine_Size  5624 non-null   float64
#  8   Mileage      5624 non-null   int64
#  9   Negotiable   5624 non-null   bool
#  10  Price        5624 non-null   int64
# dtypes: bool(1), float64(1), int64(3), object(6)
# memory usage: 445.0+ KB

# %% [markdown]
# Kode berikut digunakan untuk menampilkan statistik deskriptif pada kolom yang bertipe numerik, seperti `Year`, `Engine_Size`, `Mileage`, dan `Price`:

# %%
# Daftar kolom numerik untuk statistik deskriptif
desc = [
    'Year',
    'Engine_Size',
    'Mileage',
    'Price'
]

# Menampilkan statistik deskriptif untuk kolom yang dipilih
df[desc].describe()
# Out:
#               Year  Engine_Size       Mileage          Price
# count  5624.000000  5624.000000  5.624000e+03    5624.000000
# mean   2014.101885     3.295430  1.509234e+05   53074.058144
# std       5.791606     1.515108  3.828360e+05   70155.340614
# min    1963.000000     1.000000  1.000000e+02       0.000000
# 25%    2012.000000     2.000000  3.800000e+04       0.000000
# 50%    2016.000000     3.000000  1.030000e+05   36500.000000
# 75%    2018.000000     4.500000  1.960000e+05   72932.500000
# max    2022.000000     9.000000  2.000000e+07  850000.000000

# %%
# Menampilkan statistik deskriptif untuk kolom yang bertipe object dan bool
df.describe(include=['object', 'bool'])
# Out:
#                 Type  Region    Make  Gear_Type Origin Options Negotiable
# count           5624    5624    5624       5624   5624    5624       5624
# unique           347      27      58          2      4       3          2
# top     Land Cruiser  Riyadh  Toyota  Automatic  Saudi    Full      False
# freq             269    2272    1431       4875   4188    2233       3828

# %% [markdown]
# Penjelasan ini dapat membantu menjelaskan setiap bagian dari kode secara ringkas dan memberikan insight ke hasil output yang diberikan dari dataset.

# %% [markdown]
# ### **Data Splitting**

# %%
# feature
X=df.drop('Price',axis=1)

y=df['Price']

# %%
## split data
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=2020)

# %%
car_test=X_test.join(y_test).sort_index()
car_test
# Out:
#               Type  Region      Make  Gear_Type       Origin    Options  Year  \
# 1            Yukon  Riyadh       GMC  Automatic        Saudi       Full  2014
# 5              CX3    Abha     Mazda  Automatic        Saudi  Semi Full  2019
# 10            C300  Makkah  Chrysler  Automatic        Saudi       Full  2013
# 14           Hilux   Yanbu    Toyota  Automatic        Saudi       Full  2014
# 15    Land Cruiser   Aseer    Toyota     Manual  Gulf Arabic  Semi Full  1982
# ...            ...     ...       ...        ...          ...        ...   ...
# 5613        Taurus  Dammam      Ford  Automatic        Other  Semi Full  2016
# 5615             6  Jeddah     Mazda  Automatic        Saudi  Semi Full  2017
# 5616           CX9  Qassim     Mazda  Automatic        Saudi       Full  2020
# 5620        Altima  Jeddah    Nissan  Automatic        Saudi  Semi Full  2020
# 5623            ES  Jeddah     Lexus  Automatic        Other       Full  2017
#
# ...

# %%
df_train=X_train.join(y_train).sort_index()
df_train
# Out:
#              Type          Region        Make  Gear_Type       Origin  \
# 0         Corolla            Abha      Toyota     Manual        Saudi
# 2     Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic
# 3          Optima  Hafar Al-Batin         Kia  Automatic        Saudi
# 4              FJ          Riyadh      Toyota  Automatic        Saudi
# 6       Cayenne S          Riyadh     Porsche  Automatic        Saudi
# ...           ...             ...         ...        ...          ...
# 5617        Yukon          Jubail         GMC  Automatic        Saudi
# 5618     Suburban          Riyadh         GMC  Automatic        Saudi
# 5619      X-Trail          Jeddah      Nissan  Automatic        Saudi
# 5621        Yukon          Dammam         GMC  Automatic        Saudi
# 5622           RX          Dammam       Lexus  Automatic  Gulf Arabic
#
#         Options  Year  Engine_Size  Mileage  Negotiable   Price
# ...

# %% [markdown]
# ### **Exploratory Data Analysis**

# %% [markdown]
# **Analisis Data Eksploratif (EDA)** digunakan untuk menyelidiki data dan merangkum wawasan utama. Analisis ini membantu kita mendapatkan **pemahaman dasar** tentang data, termasuk **distribusi**, **nilai kosong**, dan lainnya. EDA memungkinkan kita untuk lebih memahami data sebelum melakukan analisis lebih lanjut.
#
# Dalam konteks ini, kolom **Harga** berfungsi sebagai **variabel target**, sementara kolom lainnya merupakan **variabel independen**. Variabel independen ini terbagi menjadi dua kategori: **variabel numerik** dan **variabel kategorikal**.
#
# Berikut adalah pembagian variabel tersebut:
#
# - **Variabel Numerik**: Tahun, Ukuran Mesin, Jarak Tempuh, Harga
# - **Variabel Kategorikal**: Jenis Mobil, Wilayah, Merek, Tipe Transmisi, Asal, Opsi, Dapat Dinegosiasikan
#
# Dengan memisahkan variabel ini, kita dapat melakukan **analisis yang lebih terstruktur** dan terfokus pada setiap jenis data.

# %% [markdown]
# #### **Variabel Numerikal**

# %%
# Pairplot untuk variabel numerik
numerical_vars = ['Year', 'Engine_Size', 'Mileage', 'Price']
pair_plot = sns.pairplot(df_train[numerical_vars], aspect=1.2, diag_kind='kde') 
pair_plot.fig.suptitle('Visualisasi Hubungan Variabel Numerik', y=1.02)
plt.grid()
plt.show()

# %% [markdown]
# Analisis:
#
# Berdasarkan grafik Pair Plot di atas, dapat dilihat adanya variasi dalam tingkat korelasi antar variabel. Berikut adalah ringkasan korelasi untuk setiap variabel:
#
# - `Year`: Memiliki hubungan yang lemah dengan Engine_Size, namun menunjukkan korelasi yang lebih kuat dengan Mileage dan Price.
# - `Engine_Size`: Korelasinya cenderung lemah dengan Year, Mileage, dan Price.
# - `Mileage`: Memiliki korelasi yang kuat dengan Year, sementara korelasinya dengan Engine_Size dan Price tergolong lemah.
# - `Price`: Terdapat korelasi yang kuat dengan Year, namun hubungannya dengan Engine_Size dan Mileage lebih lemah.

# %% [markdown]
# #### **Variabel Kategorikal**

# %% [markdown]
# Pada variabel kategorikal, akan dilakukan analisis untuk mengeksplorasi setiap kategori dan merangkum informasi penting. Langkah selanjutnya adalah menyusun peringkat serta menghitung frekuensi dari masing-masing nilai, sehingga dapat diketahui perusahaan mobil bekas yang paling sering tampil, jenis mobil bekas yang paling populer, wilayah dengan jumlah mobil bekas terbanyak, asal mobil, serta faktor-faktor lainnya.

# %% [markdown]
# ##### **Distribusi Harga Mobil Bekas**

# %%
plt.figure(figsize=(14, 8))
sns.histplot(df_train['Price'], kde=True, bins=30, color='blue')
plt.title('Distribusi Harga Mobil Bekas', weight='bold', size = 13)
plt.xlabel('Price')
plt.ylabel('Density')
plt.show()

# %%
print(df_train.Price.describe())
# Out:
# count      3936.000000
# mean      52355.257368
# std       67787.759803
# min           0.000000
# 25%           0.000000
# 50%       36000.000000
# 75%       73000.000000
# max      800000.000000
# Name: Price, dtype: float64

# %% [markdown]
# Berdasarkan visualisasi di atas, terlihat bahwa:
#
# - Harga (Price) dari mobil bekas menunjukkan distribusi yang cenderung right-skewed, di mana sebagian besar harga dalam dataset relatif lebih rendah, dengan nilai < 73,000.
# - Dalam konteks distribusi ini, nilai yang lebih tinggi dari rata-rata cenderung lebih jarang terjadi dan berada di ekor sebelah kanan dari distribusi. Ini menandakan distribusi yang positively skewed di mana rata-rata (52,335) lebih besar daripada nilai median (36,000).
#
# Distribusi ini menunjukkan bahwa sebagian besar mobil bekas memiliki harga yang lebih rendah, namun terdapat beberapa harga yang jauh lebih tinggi, yang menarik rata-rata ke atas.

# %% [markdown]
# ##### **10 Wilayah Mobil Bekas Terbaik & Asal Mobil Bekas**

# %%
# 10 Wilayah Mobil Bekas Terbaik & Asal Mobil Bekas
plt.figure(figsize=(15,7))

plt.subplot(1,2,1)
sns.countplot(x=df_train['Region'], order = df_train['Region'].value_counts().iloc[:10].index,palette='viridis')
plt.title('10 Wilayah Mobil Bekas', size = 15)
plt.xticks(rotation = 30, size = 10)

plt.subplot(1,2,2)
sns.countplot(x=df_train['Origin'], order = df_train['Origin'].value_counts().index,palette='viridis')
plt.title('Asal Mobil Bekas', size = 15)
plt.xticks(rotation = 30, size = 10)

plt.show()

# %% [markdown]
# dapat kita lihat bahwa Riyadh adalah wilayah dengan jumlah mobil bekas terbanyak (sekitar 1500 mobil), sementara Saudi menjadi asal mobil bekas terbanyak dengan jumlah yang jauh lebih besar (sekitar 3000 mobil). Hal ini menunjukkan adanya keterkaitan antara wilayah dan asal mobil. Namun, terdapat variabel `Unknown` dan `Other` pada grafik asal mobil, yang bisa membuat data menjadi redundan dan menimbulkan kebisingan. Untuk menangani masalah ini, kita akan menggabungkan data dari variabel `Unknown` ke dalam `Other` pada tahap pembersihan data.

# %% [markdown]
# ##### **Tipe dan Jumlah Tipe Transmisi, Pilihan Opsi, serta Status Negosiasi pada Mobil Bekas**

# %%
# Gear Type
plt.figure(figsize=(14, 8))
ax1 = sns.countplot(x='Gear_Type', data=df_train, palette='viridis')
plt.title('Distribusi Jenis Transmisi pada Mobil Bekas')
plt.xlabel('Jenis Transmisi')
plt.ylabel('Jumlah')
for p in ax1.patches:
    ax1.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.show()

# Options
plt.figure(figsize=(14, 8))
ax2 = sns.countplot(x='Options', data=df_train, palette='viridis', order=df_train['Options'].value_counts().index)
plt.title('Distribusi Opsi pada Mobil Bekas')
plt.xlabel('Opsi')
plt.ylabel('Jumlah')
plt.xticks(rotation=45, ha='right')
for p in ax2.patches:
    ax2.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.show()

# Negotiable
plt.figure(figsize=(14, 8))
ax3 = sns.countplot(x='Negotiable', data=df_train, palette='viridis')
plt.title('Distribusi Kemungkinan Harga Dapat Dinegosiasikan pada Mobil Bekas')
plt.xlabel('Dapat Dinegosiasikan')
plt.ylabel('Jumlah')
for p in ax3.patches:
    ax3.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.show()

# %% [markdown]
# Berdasarkan data di atas, berikut adalah kesimpulan dari hasil analisis:
#
# - Sebagian besar mobil bekas yang tersedia menggunakan transmisi otomatis (Automatic) dibandingkan transmisi manual.
# - Terdapat tiga kategori opsi pada mobil bekas, yaitu Full (1556), Standar (1267), dan Semi Full (1103). Opsi Full memiliki jumlah terbanyak dibandingkan dengan dua opsi lainnya.
# - Mayoritas mobil bekas tidak dapat dinegosiasikan (Non-Negotiable), sedangkan hanya sebagian kecil yang bisa dinegosiasikan (Negotiable).

# %% [markdown]
# ##### **Penjualan Merek Mobil Bekas Terpopuler**

# %%
plt.figure(figsize=(14,6))

plt5 = df_train.Make.value_counts().plot(kind= 'bar', color= 'blue')
plt.title('Make')
plt5.set(xlabel = 'Manufacturer', ylabel='Frequency')

plt.show()

# %% [markdown]
# Berdasarkan data diatas :
#
# - Toyota, Hyundai, dan Ford menjadi tiga merek kendaraan yang paling sering dipilih oleh konsumen mobil bekas.

# %%
plt.figure(figsize=(20, 8))

df_regPrice = pd.DataFrame(df_train.groupby(['Region'])['Price'].mean().sort_values(ascending=False))
df_regPrice.plot.bar(colormap='viridis')

plt.title('Region vs Average Price')
plt.xlabel('Region')
plt.ylabel('Average Price')

plt.show()

# %% [markdown]
# ## **Data Preprocessing**

# %% [markdown]
# Pada tahap ini, kita akan melakukan proses perbaikan atau penghapusan data yang salah, rusak, formatnya tidak sesuai, duplikat, atau tidak lengkap dalam sebuah dataset. Memiliki data yang bersih akan meningkatkan produktivitas secara keseluruhan dan memungkinkan informasi berkualitas tinggi untuk mendukung pengambilan keputusan yang lebih baik.

# %% [markdown]
# #### **Check the detail of dataset**

# %%
# Membuat duplikasi dataframe
car_train = df_train.copy()

# %%
# Periksa info dataset lebih detail
listItem = []

for col in car_train.columns:
    listItem.append([col, car_train[col].dtype, car_train[col].isna().sum(), round((car_train[col].isna().sum()/len(car_train[col]))*100, 2),
                    car_train[col].nunique(), car_train[col].drop_duplicates().sample(2).values]);

car_train_desc = pd.DataFrame(columns=['dataFeatures', 'dataType', 'null', 'nullPct', 'unique', 'uniqueSample'],
                     data=listItem)
car_train_desc
# Out:
#    dataFeatures dataType  null  nullPct  unique           uniqueSample
# 0          Type   object     0      0.0     314  [Outlander, Traverse]
# 1        Region   object     0      0.0      26         [Dammam, Taef]
# 2          Make   object     0      0.0      56          [Foton, MINI]
# 3     Gear_Type   object     0      0.0       2    [Automatic, Manual]
# 4        Origin   object     0      0.0       4   [Gulf Arabic, Other]
# 5       Options   object     0      0.0       3       [Full, Standard]
# 6          Year    int64     0      0.0      47           [2016, 2022]
# 7   Engine_Size  float64     0      0.0      67             [4.3, 5.7]
# 8       Mileage    int64     0      0.0    1343       [107601, 213000]
# 9    Negotiable     bool     0      0.0       2          [True, False]
# 10        Price    int64     0      0.0     403             [0, 78000]

# %% [markdown]
# Seperti yang telah dijelaskan sebelumnya, variabel 'Asal' mengandung data yang redundan, yaitu 'Unknown' dan 'Other', karena secara konseptual memiliki makna yang sama. Oleh karena itu, kami akan menyatukan kedua nilai tersebut dengan mengganti 'Unknown' menjadi 'Other' demi konsistensi."

# %%
# Ganti 'Unknown' menjadi 'Other'
car_train['Origin'] = car_train['Origin'].replace('Unknown','Other')

# %%
car_train['Origin'].value_counts()
# Out:
# Origin
# Saudi          2936
# Other           514
# Gulf Arabic     486
# Name: count, dtype: int64

# %% [markdown]
# ##### **Check for Missing Value and Duplicated Rows**

# %%
# Heatmap missing value
plt.figure(figsize=(14, 8))
sns.heatmap(car_train.isnull(), cmap='viridis', cbar=False)
plt.title('Heatmap Missing Value in Saudi Arabia Used Cars')
plt.show()

# %% [markdown]
# Dapat kita lihat Heatmap diatas bahwa tidak ada nilai yang hilang dalam dataset ini. Langkah selanjutnya adalah memeriksa kemungkinan adanya data yang duplikat. Data duplikat menunjukkan bahwa ada entri yang muncul lebih dari sekali dalam dataset, yang bisa terjadi akibat kesalahan saat memasukkan data atau cara pengumpulan data yang kurang tepat. Menghilangkan data duplikat akan membantu kita mendapatkan hasil analisis yang lebih akurat. Namun, sebelum menghapus data yang terduplikasi, perlu dilakukan analisis lebih lanjut untuk memastikannya.

# %% [markdown]
# Kita juga harus memeriksa data duplikasi dalam dataset kita. Duplikasi berarti kita telah mengulang data dalam kumpulan data kita. Hal ini dapat disebabkan oleh hal-hal seperti kesalahan entri data atau metode pengumpulan data. Menghapus duplikasi akan membuat kita membuat pengamatan terbaik yang kita miliki.

# %%
# Check for duplicated rows
print("Number of duplicate rows: ", sum(car_train.duplicated()))
# Out:
# Number of duplicate rows:  1

# %% [markdown]
# Seperti yang bisa kita lihat bahwa ada 1 baris yang telah diduplikasi sebelumnya. Jadi kita harus menghapus (drop) baris yang terduplikasi untuk mendapatkan data yang bersih seperti yang kita inginkan.

# %%
# Drop duplicated rows
car_train.drop_duplicates(inplace=True)
print("Number of duplicate rows: ", sum(car_train.duplicated()))
# Out:
# Number of duplicate rows:  0

# %% [markdown]
# Setelah menghapus baris-baris yang terduplikasi, langkah berikutnya adalah mempertimbangkan untuk menghilangkan kolom-kolom yang tidak akan digunakan ke depannya. Baris yang kita hapus merupakan baris yang memiliki relevansi rendah terhadap kolom lain atau model yang kita bangun.

# %% [markdown]
# #### **Delete Column Unrelevant**

# %% [markdown]
# Berdasarkan pengetahuan terkait domain, kolom Negotiable tidak memiliki pengaruh signifikan terhadap kolom lain. Oleh karena itu, kolom Negotiable akan dihapus terlebih dahulu. Selain itu, kita juga akan membatasi nilai-nilai ekstrem pada variabel yang berpotensi mempengaruhi hasil analisis.

# %%
# Delete column unrelevant (Negotiable) for analysis
car_train = car_train.drop(['Negotiable'], axis=1)
car_train.head()
# Out:
#           Type          Region        Make  Gear_Type       Origin    Options  \
# 0      Corolla            Abha      Toyota     Manual        Saudi   Standard
# 2  Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic       Full
# 3       Optima  Hafar Al-Batin         Kia  Automatic        Saudi  Semi Full
# 4           FJ          Riyadh      Toyota  Automatic        Saudi       Full
# 6    Cayenne S          Riyadh     Porsche  Automatic        Saudi       Full
#
#    Year  Engine_Size  Mileage   Price
# 0  2013          1.4   421000       0
# 2  2015          5.0   140000  260000
# 3  2015          2.4   220000   42000
# 4  2020          4.0    49000       0
# 6  2012          4.8   189000   85000

# %%
# Delete column unrelevant (Negotiable) for analysis
car_test = car_test.drop(['Negotiable'], axis=1)
car_test.head()
# Out:
#             Type  Region      Make  Gear_Type       Origin    Options  Year  \
# 1          Yukon  Riyadh       GMC  Automatic        Saudi       Full  2014
# 5            CX3    Abha     Mazda  Automatic        Saudi  Semi Full  2019
# 10          C300  Makkah  Chrysler  Automatic        Saudi       Full  2013
# 14         Hilux   Yanbu    Toyota  Automatic        Saudi       Full  2014
# 15  Land Cruiser   Aseer    Toyota     Manual  Gulf Arabic  Semi Full  1982
#
#     Engine_Size  Mileage   Price
# 1           8.0    80000  120000
# 5           2.0    25000   58000
# 10          5.7      200   55000
# 14          2.7      209       0
# 15          4.6   340000       0

# %%
car_train.describe()
# Out:
#               Year  Engine_Size       Mileage          Price
# count  3935.000000  3935.000000  3.935000e+03    3935.000000
# mean   2014.071410     3.293571  1.510285e+05   52357.126557
# std       5.756297     1.520088  3.982430e+05   67796.273437
# min    1963.000000     1.000000  1.000000e+02       0.000000
# 25%    2012.000000     2.000000  3.800000e+04       0.000000
# 50%    2016.000000     3.000000  1.038850e+05   36000.000000
# 75%    2018.000000     4.500000  1.960000e+05   73000.000000
# max    2022.000000     9.000000  2.000000e+07  800000.000000

# %% [markdown]
# Berdasarkan informasi di atas, dapat dilihat bahwa:
#
#
# - Sebanyak 25% dari data pada kolom Price memiliki nilai 0, yang tidak masuk akal, karena tidak mungkin pelanggan menjual mobil bekas secara gratis.
#
# - Kolom Mileage yang menggunakan satuan mil menunjukkan nilai maksimum sebesar 20,000,000 mil. Jika dikonversikan, jarak ini setara dengan 32,186,880 kilometer. Angka tersebut terlalu besar dan tidak realistis untuk mayoritas kendaraan pribadi."

# %%
# Jumlah Baris Data Dengan Nilai 'Price' == 0
car_train[car_train['Price'] == 0]['Price'].count()
# Out:
# 1258

# %%
# Drop Baris Data Dengan Nilai 'Price' == 0
car_train = car_train[car_train['Price'] != 0]
car_train.head(10)
# Out:
#             Type          Region        Make  Gear_Type       Origin  \
# 2    Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic
# 3         Optima  Hafar Al-Batin         Kia  Automatic        Saudi
# 6      Cayenne S          Riyadh     Porsche  Automatic        Saudi
# 7         Sonata          Riyadh     Hyundai  Automatic        Saudi
# 8         Avalon          Riyadh      Toyota  Automatic        Saudi
# 11  Land Cruiser          Riyadh      Toyota  Automatic        Saudi
# 12            LS          Dammam       Lexus  Automatic        Saudi
# 13            FJ          Riyadh      Toyota  Automatic        Saudi
# 17  Land Cruiser          Riyadh      Toyota  Automatic        Saudi
# 18        Tucson          Jeddah     Hyundai  Automatic        Saudi
#
#       Options  Year  Engine_Size  Mileage   Price
# 2        Full  2015          5.0   140000  260000
# 3   Semi Full  2015          2.4   220000   42000
# 6        Full  2012          4.8   189000   85000
# ...

# %%
# Meninjau ulang untuk melihat apakah nilai terendah dari fitur 'Price' masih terlihat tidak masuk akal.
car_train.sort_values(by= 'Price', ascending= 1, inplace= True)
car_train.head(10)
# Out:
#          Type     Region       Make  Gear_Type Origin    Options  Year  \
# 3131    Yukon     Jubail        GMC  Automatic  Saudi       Full  2019
# 3474    Yaris     Najran     Toyota  Automatic  Saudi   Standard  2019
# 1534    Yukon     Jeddah        GMC  Automatic  Saudi   Standard  2021
# 5424    Yaris     Najran     Toyota  Automatic  Saudi       Full  2018
# 2366  Corolla     Makkah     Toyota  Automatic  Saudi  Semi Full  2020
# 4124   Duster    Al-Ahsa    Renault  Automatic  Saudi       Full  2017
# 5035     Kona  Al-Medina    Hyundai  Automatic  Saudi   Standard  2020
# 65     Malibu       Arar  Chevrolet  Automatic  Saudi   Standard  2021
# 789       CX5     Khobar      Mazda  Automatic  Saudi   Standard  2021
# 3362   Tucson     Riyadh    Hyundai  Automatic  Saudi  Semi Full  2019
#
#       Engine_Size  Mileage  Price
# 3131          5.3    50000      1
# 3474          1.6    85000    950
# 1534          5.3     4000   1000
# 5424          1.5   169000   1046
# ...

# %%
car_train[car_train['Price'] == 1]['Price'].count()
# Out:
# 1

# %% [markdown]
# Setelah dilakukan peninjauan ulang, ditemukan bahwa terdapat 1 baris data dengan nilai yang tidak wajar, yaitu 'Price' == 1.
# Harga ini seolah-olah menunjukkan bahwa mobil diberikan secara gratis kepada pelanggan. Oleh karena itu, baris data dengan 'Price' == 1 akan dihapus dari dataset.

# %%
car_train = car_train[car_train['Price'] != 1]
car_train.head(10)
# Out:
#          Type     Region       Make  Gear_Type Origin    Options  Year  \
# 3474    Yaris     Najran     Toyota  Automatic  Saudi   Standard  2019
# 1534    Yukon     Jeddah        GMC  Automatic  Saudi   Standard  2021
# 5424    Yaris     Najran     Toyota  Automatic  Saudi       Full  2018
# 2366  Corolla     Makkah     Toyota  Automatic  Saudi  Semi Full  2020
# 4124   Duster    Al-Ahsa    Renault  Automatic  Saudi       Full  2017
# 5035     Kona  Al-Medina    Hyundai  Automatic  Saudi   Standard  2020
# 65     Malibu       Arar  Chevrolet  Automatic  Saudi   Standard  2021
# 789       CX5     Khobar      Mazda  Automatic  Saudi   Standard  2021
# 3362   Tucson     Riyadh    Hyundai  Automatic  Saudi  Semi Full  2019
# 5032  Elantra     Jubail    Hyundai  Automatic  Saudi  Semi Full  2018
#
#       Engine_Size  Mileage  Price
# 3474          1.6    85000    950
# 1534          5.3     4000   1000
# 5424          1.5   169000   1046
# 2366          1.1    26000   1086
# ...

# %% [markdown]
# #### **Handling Outliers**

# %% [markdown]
# langkah pertama yang harus dilakukan adalah menemukan outlier terlebih dahulu. Outlier memiliki dampak signifikan pada dataset kita, karena dapat meningkatkan varians error dan mengurangi kekuatan uji statistik. Selain itu, outlier dapat menyebabkan bias atau mempengaruhi estimasi, serta berpotensi mengganggu asumsi dasar dari regresi dan model statistik lainnya.
#
# Tantangannya adalah, bagaimana kita dapat mendeteksi outlier? Apakah ada outlier positif dan negatif dalam dataset kita? Bagaimana kita dapat mengeliminasi outlier dan membersihkan dataset tanpa kehilangan banyak informasi penting? Semua ini akan kita bahas lebih lanjut dalam proyek ini.
#
# Pada tahap ini, kita akan melihat plot distribusi untuk setiap variabel numerik dalam dataset sebelum memutuskan baris dan kolom mana yang perlu dihapus karena mungkin mengandung outlier.

# %%
plt.figure(figsize=(15, 10))
sns.set(style="whitegrid")

# Plot distribusi untuk 'Year'
plt.subplot(221)
sns.histplot(car_train['Year'], bins=20, color='salmon', kde=True)
plt.title('Distribusi Tahun Mobil Bekas', fontsize=13)
plt.xlabel('Tahun', fontsize=11)
plt.ylabel('Frekuensi', fontsize=11)

# Plot distribusi untuk 'Engine_Size'
plt.subplot(222)
sns.histplot(car_train['Engine_Size'], bins=20, color='salmon', kde=True)
plt.title('Distribusi Ukuran Mesin Mobil Bekas', fontsize=13)
plt.xlabel('Ukuran Mesin (Liter)', fontsize=11)
plt.ylabel('Frekuensi', fontsize=11)

# Plot distribusi untuk 'Mileage'
plt.subplot(223)
sns.histplot(car_train['Mileage'], bins=20, color='salmon', kde=True)
plt.title('Distribusi Jarak Tempuh Mobil Bekas', fontsize=13)
plt.xlabel('Jarak Tempuh (Mil)', fontsize=11)
plt.ylabel('Frekuensi', fontsize=11)

# Plot distribusi untuk 'Price'
plt.subplot(224)
sns.histplot(car_train['Price'], bins=20, color='salmon', kde=True)
plt.title('Distribusi Harga Mobil Bekas', fontsize=13)
plt.xlabel('Harga (Riyad)', fontsize=11)
plt.ylabel('Frekuensi', fontsize=11)

# Menata ulang layout agar lebih rapi
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
ax = car_train.boxplot(column=['Year', 'Engine_Size', 'Mileage', 'Price'], grid=False, patch_artist=True)

# Customizing boxplot
colors = ['#3498db', '#e74c3c', '#2ecc71', '#f1c40f']
for patch, color in zip(ax.artists, colors):
    patch.set_facecolor(color)

# Setting the plot title and labels
plt.title("Boxplot untuk Variabel Numerik", fontsize=14)
plt.ylabel("Nilai", fontsize=12)
plt.xticks(rotation=45, fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan visualisasi di atas, ditemukan beberapa outlier pada fitur Mileage dan Price. Untuk menangani hal ini, dilakukan pemrosesan data menggunakan metode IQR serta pemahaman terhadap konteks domain. Dengan langkah-langkah tersebut, model yang dibangun diharapkan mampu memberikan prediksi yang lebih akurat dengan mempertimbangkan batasan yang telah ditentukan dalam dataset yang sudah dibersihkan. Tujuannya adalah untuk menghasilkan prediksi yang lebih stabil, khususnya ketika nilai yang diprediksi berada dalam rentang yang telah ditetapkan.

# %% [markdown]
# `Year`

# %%
# Memeriksa Kolom 'Year' Dengan Statistik Deskriptif
car_train['Year'].describe()
# Out:
# count    2676.000000
# mean     2014.820628
# std         5.073954
# min      1963.000000
# 25%      2013.000000
# 50%      2016.000000
# 75%      2018.000000
# max      2021.000000
# Name: Year, dtype: float64

# %%
# Check the 'Year' outliers with boxplot
plt.figure(figsize=(15,2))
sns.boxplot(x=car_train["Year"])
# Out:
# <Axes: xlabel='Year'>

# %%
# Sort the min 10 data of Year
car_train.sort_values(by='Year', ascending=1, inplace=True)
car_train.head(10)
# Out:
#                  Type   Region       Make  Gear_Type Origin    Options  Year  \
# 5012            Other   Riyadh       Ford     Manual  Saudi   Standard  1963
# 2262           Impala  Al-Ahsa  Chevrolet  Automatic  Other       Full  1964
# 3082  Land Cruiser 70   Riyadh     Toyota     Manual  Saudi   Standard  1978
# 663             Other   Qassim      Other     Manual  Other   Standard  1980
# 62                SEL   Tabouk   Mercedes  Automatic  Saudi       Full  1986
# 1419     Land Cruiser   Najran     Toyota     Manual  Saudi  Semi Full  1988
# 2753            The 7   Dammam        BMW  Automatic  Other       Full  1989
# 5044              SEL   Riyadh   Mercedes  Automatic  Other       Full  1989
# 3143            The 7   Dammam        BMW  Automatic  Other       Full  1989
# 4096              SEL   Dammam   Mercedes  Automatic  Other       Full  1990
#
#       Engine_Size  Mileage   Price
# 5012          1.0      300   22000
# 2262          1.2   100000   75000
# ...

# %%
print("Count of data Year less than 10% percentile :",((car_train[car_train['Year'] < 2009].count()['Year'])/3824)*100,"%")
# Out:
# Count of data Year less than 10% percentile : 6.72071129707113 %

# %% [markdown]
# Seperti yang dapat kita lihat:
#
# - Dari boxplot, outlier berada di sebelah kiri - jadi kami urutkan dan deskripsikan data terendah dari kolom Year.
# - Kita bisa melihat bahwa outlier berada pada tahun 1963 dan 1964. Namun, kita harus mempertimbangkan tahun tersebut bersama variabel lainnya (Mileage, Type, Make, Gear Type & Options) sehingga mungkin saja mobil tersebut bisa dijual dengan harga tersebut - Dapat Diterima.
# - Tidak ada jarak/lompatan yang terlalu jauh antara 10 nilai minimum tahun ke tahun lainnya.
# - Nilai minimum berada di dekat 10% rentang data dari dataset - Variasi yang Baik.

# %% [markdown]
# `Engine_Size`

# %%
# Check the 'Engine_Size' outliers with boxplot
plt.figure(figsize=(15,2))
sns.boxplot(x=car_train["Engine_Size"])
# Out:
# <Axes: xlabel='Engine_Size'>

# %%
# Sort the max 10 data of Engine_Size
car_train.sort_values(by='Engine_Size', ascending=0, inplace=True)
car_train.head(10)
# Out:
#               Type   Region        Make  Gear_Type Origin    Options  Year  \
# 59           Camry     Taef      Toyota  Automatic  Saudi  Semi Full  2001
# 650              E   Jeddah    Mercedes     Manual  Other  Semi Full  2017
# 1547       Marquis   Riyadh        Ford  Automatic  Other       Full  2008
# 3525            FJ     Hail      Toyota  Automatic  Saudi       Full  2014
# 3848   Range Rover   Jeddah  Land Rover  Automatic  Saudi  Semi Full  2013
# 1994      Suburban  Al-Jouf   Chevrolet  Automatic  Saudi  Semi Full  2011
# 3244  Land Cruiser   Qassim      Toyota  Automatic  Saudi       Full  2012
# 5293       Durango   Riyadh       Dodge  Automatic  Saudi       Full  2019
# 2758             S   Jeddah    Mercedes  Automatic  Saudi       Full  2013
# 4869     Silverado   Dammam   Chevrolet  Automatic  Saudi  Semi Full  2018
#
#       Engine_Size  Mileage   Price
# 59            9.0   150000   15000
# 650           9.0   134000  155000
# 1547          9.0      115   17000
# ...

# %%
print("Count of data Engine_Size more than 90% percentile :",((car_train[car_train['Engine_Size'] > 5.3].count()['Engine_Size'])/3824)*100,"%")
# Out:
# Count of data Engine_Size more than 90% percentile : 6.956066945606694 %

# %% [markdown]
# Seperti yang dapat kita lihat:
#
# - Dari boxplot, outlier berada di sebelah kanan - jadi kami urutkan dan deskripsikan data maksimum dari kolom Engine_Size.
# - Kita bisa melihat bahwa outlier berada pada rentang 7 hingga 9 pada data Engine_Size. Namun, seperti yang kita ketahui, mungkin saja ada mobil dengan ukuran mesin tersebut yang sesuai dengan harga yang ada. (Dengan mempertimbangkan variabel lain pada data tersebut). - Dapat Diterima.
# - Tidak ada lompatan yang signifikan pada 10 nilai maksimum dari Engine_Size - Dapat Diterima.
# - Nilai maksimum berada di dekat 10% rentang data dari dataset - Variasi yang Baik.

# %% [markdown]
# `Mileage`

# %%
# Check the 'Mileage' outliers with boxplot
plt.figure(figsize=(15,2))
sns.boxplot(x=car_train["Mileage"])
# Out:
# <Axes: xlabel='Mileage'>

# %%
# Sort the max 10 data of Mileage
car_train.sort_values(by='Mileage', ascending=0, inplace=True)
car_train.head(10)
# Out:
#              Type  Region        Make  Gear_Type Origin    Options  Year  \
# 3403        Optra  Riyadh   Chevrolet     Manual  Other  Semi Full  2009
# 572         Camry   Yanbu      Toyota  Automatic  Other       Full  1998
# 4193       Innova  Riyadh      Toyota     Manual  Saudi   Standard  2013
# 1412  Trailblazer  Jeddah   Chevrolet  Automatic  Other       Full  2004
# 915    Pathfinder  Riyadh      Nissan  Automatic  Saudi   Standard  1998
# 4875   Pathfinder  Riyadh      Nissan  Automatic  Saudi       Full  2008
# 3387       Fusion    Hail        Ford  Automatic  Saudi       Full  2010
# 1334        Prado  Makkah      Toyota     Manual  Saudi  Semi Full  2006
# 3797      Marquis  Riyadh        Ford  Automatic  Saudi  Semi Full  2005
# 333   Range Rover  Jeddah  Land Rover  Automatic  Saudi       Full  2009
#
#       Engine_Size   Mileage  Price
# 3403          1.6  20000000   9000
# 572           2.5   4500000  15000
# 4193          2.7   3640000  30000
# ...

# %%
print("Count of data Mileage more than 90% percentile :",((car_train[car_train['Mileage'] > 284000.0].count()['Mileage'])/3824)*100,"%")
# Out:
# Count of data Mileage more than 90% percentile : 6.9822175732217575 %

# %% [markdown]
# Seperti yang dapat kita lihat:
#
# - Dari boxplot di atas, outlier berada di sebelah kanan - jadi kami urutkan dan deskripsikan data maksimum dari kolom Mileage.
# - Kita dapat melihat bahwa outlier (nilai ekstrem) berada di 2.00 le7 dengan Engine_Size 1.6 dan harga 9000. Kami berasumsi bahwa ini mungkin merupakan outlier yang disebabkan oleh kesalahan manusia atau faktor lain. Karena jarak antara 2.000.000 dan 4.500.000 terlalu besar - Tidak Dapat Diterima.
# - Nilai maksimum berada di dekat 10% rentang data dari dataset - Variasi yang Baik.
#
# Oleh karena itu, kami melakukan pemotongan pada Mileage yang lebih dari 4.500.000. Selain itu,

# %%
# Drop the Outliers
car_train = car_train[(car_train['Mileage'] <= 700000)]
car_train
# Out:
#               Type  Region        Make  Gear_Type       Origin    Options  \
# 536         Datsun  Riyadh      Nissan     Manual        Other       Full
# 1609         Yukon  Riyadh         GMC  Automatic        Saudi  Semi Full
# 1264  Land Cruiser  Dammam      Toyota     Manual        Saudi   Standard
# 4476  Land Cruiser  Jeddah      Toyota     Manual        Saudi       Full
# 2663         Hiace  Riyadh      Toyota     Manual        Saudi   Standard
# ...            ...     ...         ...        ...          ...        ...
# 5001        Sonata  Jeddah     Hyundai  Automatic        Saudi   Standard
# 1276         Delta   Aseer    Daihatsu     Manual        Saudi       Full
# 3071      Defender  Jeddah  Land Rover  Automatic        Saudi       Full
# 4240           CT4  Jeddah    Cadillac  Automatic  Gulf Arabic  Semi Full
# 3488       Cadenza  Tabouk         Kia  Automatic  Gulf Arabic       Full
#
#       Year  Engine_Size  Mileage   Price
# ...

# %% [markdown]
# `Price`

# %%
car_train['Price'].describe()
# Out:
# count      2658.000000
# mean      77275.693002
# std       69840.731694
# min         950.000000
# 25%       35000.000000
# 50%       58000.000000
# 75%       93875.000000
# max      800000.000000
# Name: Price, dtype: float64

# %%
# Check the 'Price' outliers with boxplot
plt.figure(figsize=(15,2))
sns.boxplot(x=car_train["Price"])
# Out:
# <Axes: xlabel='Price'>

# %%
Q1 = car_train['Price'].quantile(0.25)
Q3 = car_train['Price'].quantile(0.75)

IQR = Q3 - Q1

min_limit = Q1 - 1.5 * IQR
max_limit = Q3 + 1.5 * IQR

print(f"Q1 (25th percentile): {Q1}")
print(f"Q3 (75th percentile): {Q3}")
print(f"IQR: {IQR}")
print(f"Minimum value limit: {min_limit}")
print(f"Maximum value limit: {max_limit}")
# Out:
# Q1 (25th percentile): 35000.0
# Q3 (75th percentile): 93875.0
# IQR: 58875.0
# Minimum value limit: -53312.5
# Maximum value limit: 182187.5

# %%
# Sort the max 10 data of Mileage
car_train.sort_values(by='Price', ascending=0, inplace=True)
car_train.head(10)
# Out:
#              Type  Region         Make  Gear_Type       Origin Options  Year  \
# 4684            G  Riyadh     Mercedes  Automatic        Other    Full  2019
# 2120        Ghost  Dammam  Rolls-Royce  Automatic        Saudi    Full  2016
# 4653  Range Rover  Riyadh   Land Rover  Automatic        Other    Full  2019
# 3561  Range Rover  Riyadh   Land Rover  Automatic        Saudi    Full  2020
# 3105  Range Rover  Riyadh   Land Rover  Automatic  Gulf Arabic    Full  2020
# 1619           LX  Riyadh        Lexus  Automatic        Saudi    Full  2021
# 5139            S  Riyadh     Mercedes  Automatic  Gulf Arabic    Full  2019
# 2672            X  Dammam          BMW  Automatic  Gulf Arabic    Full  2020
# 3182           LX  Riyadh        Lexus  Automatic  Gulf Arabic    Full  2020
# 3071     Defender  Jeddah   Land Rover  Automatic        Saudi    Full  2021
#
#       Engine_Size  Mileage   Price
# 4684          4.0    39000  800000
# 2120          6.0    40000  620000
# ...

# %%
print("Count of data Price more than 90% percentile :",((car_train[car_train['Price'] > 153350].count()['Price'])/3824)*100,"%")
# Out:
# Count of data Price more than 90% percentile : 6.406903765690377 %

# %% [markdown]
# Seperti yang dapat kita lihat:
#
# - Dari boxplot di atas, outlier berada di sebelah kanan - jadi kami urutkan dan deskripsikan data maksimum dari kolom Price.
# - Tidak ada lompatan pada 10 nilai maksimum dari Price - Dapat Diterima.
# - Nilai minimum dan maksimum berada di dekat 10% rentang data dari dataset - Variasi yang Baik.
#
# Oleh karena itu, kami melakukan pemotongan pada minimum Price yang kurang dari 1000 akan kami buang untuk memaksimalkan hasil modeling

# %%
# # Drop the Outliers
car_train = car_train[(car_train['Price'] >= 1000)]
car_train
# Out:
#              Type     Region         Make  Gear_Type       Origin    Options  \
# 4684            G     Riyadh     Mercedes  Automatic        Other       Full
# 2120        Ghost     Dammam  Rolls-Royce  Automatic        Saudi       Full
# 4653  Range Rover     Riyadh   Land Rover  Automatic        Other       Full
# 3561  Range Rover     Riyadh   Land Rover  Automatic        Saudi       Full
# 3105  Range Rover     Riyadh   Land Rover  Automatic  Gulf Arabic       Full
# ...           ...        ...          ...        ...          ...        ...
# 5035         Kona  Al-Medina      Hyundai  Automatic        Saudi   Standard
# 4124       Duster    Al-Ahsa      Renault  Automatic        Saudi       Full
# 2366      Corolla     Makkah       Toyota  Automatic        Saudi  Semi Full
# 5424        Yaris     Najran       Toyota  Automatic        Saudi       Full
# 1534        Yukon     Jeddah          GMC  Automatic        Saudi   Standard
#
#       Year  Engine_Size  Mileage   Price
# ...

# %% [markdown]
# ### **Feature Selection**

# %%
# Pastikan hanya kolom numerik yang digunakan untuk matriks korelasi
numeric_df = car_train.select_dtypes(include=[np.number])

# Periksa nilai non-numerik dan tangani jika ada
# Anda dapat mengonversi nilai non-numerik menjadi NaN dan menghapusnya jika perlu
numeric_df = numeric_df.apply(pd.to_numeric, errors='coerce')

# Sekarang tampilkan matriks korelasi
plt.figure(figsize=(14, 10))
sns.heatmap(numeric_df.corr(), annot=True)
plt.title("Matriks Korelasi", size=14, weight='bold')
plt.show()

# %% [markdown]
# Berdasarkan heatmap di atas :
#
# - Matriks korelasi menunjukkan bahwa fitur Year, Engine_Size, dan Mileage tidak memiliki korelasi yang sangat kuat dengan Price. Korelasi terkuat berada pada kisaran sekitar 0.31 untuk fitur Year dengan Price.
#
# - Fitur Year dan Engine_Size menunjukkan korelasi positif dengan Price, yang artinya ketika fitur tersebut meningkat, harga (Price) juga cenderung meningkat. Sebaliknya, Mileage berkorelasi negatif dengan Price, yang berarti semakin tinggi jarak tempuh, harga cenderung menurun.

# %%
objects = car_train.columns[car_train.dtypes == 'object']

# %%
features = []

for i in objects:
    corr = round(correlation_ratio(car_train[i], car_train['Price']), 2)
    features.append(corr)

car_train_ratio = pd.DataFrame(data = [features], columns = [objects], index=['Price'])

# %%
plt.figure(figsize=(16,2))
sns.heatmap(car_train_ratio, annot=True, cbar =False)
plt.show()

# %% [markdown]
# Berdasarkan hasil visualisasi korelasi pada gambar di atas :
#
# - Fitur Type memiliki korelasi paling tinggi dengan Price sebesar 0.75. Hal ini menunjukkan bahwa tipe kendaraan memiliki pengaruh yang signifikan terhadap harga. Semakin tinggi tipe kendaraan, kemungkinan besar harga juga akan semakin tinggi.
#
# - Fitur Make juga memiliki korelasi yang cukup signifikan dengan Price sebesar 0.61. Ini menunjukkan bahwa merek kendaraan juga mempengaruhi harga, meskipun tidak sekuat pengaruh tipe kendaraan.
#
# - Fitur Options memiliki korelasi sebesar 0.33 dengan Price, yang menunjukkan bahwa semakin banyak fitur atau opsi tambahan pada kendaraan, harga juga cenderung meningkat.
#
# - Fitur lainnya seperti Region, Gear_Type, dan Origin memiliki korelasi yang rendah dengan Price. Korelasi tersebut menunjukkan bahwa faktor wilayah, jenis transmisi, dan asal kendaraan tidak terlalu berpengaruh terhadap harga kendaraan.

# %%
# Preprocessing Section
# Definisikan fitur numerik dan kategori dari data
numerical_features = ['Engine_Size', 'Mileage', 'Year']  # Sesuaikan dengan kolom numerik
categorical_features = ['Type', 'Region', 'Make', 'Gear_Type']  # Sesuaikan dengan kolom kategori

# Membuat transformer untuk preprocessing
transformer = ColumnTransformer(transformers=[
    ('num', SimpleImputer(strategy='mean'), numerical_features),  # Isi missing values untuk numerik
    ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)  # OneHotEncoding untuk kategori
])

# Scaling untuk fitur numerik
scaler_data = StandardScaler()

# %% [markdown]
# ### **Feature Engineering**

# %% [markdown]
# ##### **Encoding**

# %% [markdown]
# Setelah melakukan proses Data Cleaning, terdapat beberapa fitur kategorikal yang perlu diubah menjadi fitur numerikal untuk membantu pembuatan model prediksi. Berdasarkan hasil korelasi di gambar sebelumnya, kita dapat mengidentifikasi fitur-fitur kategorikal yang akan di-encode, yaitu:

# %% [markdown]
# - Type: Fitur Type memiliki korelasi tinggi dengan Price. Oleh karena itu, fitur ini perlu diubah menjadi numerik. Kami akan menggunakan Binary Encoding karena hanya ada dua nilai utama yang perlu diubah.
#
# - Region dan Gear_Type: Kedua fitur ini memiliki korelasi yang lebih rendah dengan Price. Kita akan menggunakan teknik One-Hot Encoding untuk mengonversi nilai-nilai di dalamnya, karena masing-masing fitur tersebut memiliki beberapa kategori yang tidak berurutan.
#
# - Make dan Origin: Fitur ini juga memiliki korelasi yang rendah dengan Price. Seperti fitur Region dan Gear_Type, kita juga akan menggunakan One-Hot Encoding untuk mengonversi kategorinya menjadi variabel dummy, sehingga model dapat memahami perbedaan antar merek dan asal kendaraan tanpa memberikan urutan tertentu.
#
# - Options: Fitur ini memiliki korelasi sedang dengan Price. Oleh karena itu, kami akan menggunakan Ordinal Encoding dengan urutan None, Standard, Semi Full, dan Full sesuai dengan tingkatan opsi yang tersedia pada kendaraan.

# %%
# Membuat Mapping Ordinal Pada Fitur 'Options'
ordinal_mapping = [{
    'col': 'Options',
    'mapping': {None: 0, 'Standard': 1, 'Semi Full': 2, 'Full': 3}
}]

ordinal_encoder = ce.OrdinalEncoder(cols=['Options'], mapping=ordinal_mapping)

# Mengubah Fitur Kategorikal Menjadi Fitur Numerikal
transformer = ColumnTransformer([
    ('One Hot', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False),  # Ubah sparse menjadi dense
     ['Region', 'Gear_Type', 'Make', 'Origin']),
    ('Ordinal', ordinal_encoder, ['Options']),
    ('Binary', ce.BinaryEncoder(), ['Type'])
], remainder='passthrough')

# %% [markdown]
# ## **Modeling and Evaluation**

# %%
# Memisahkan Independen Variabel Dengan Target
X_train = car_train.drop(columns='Price', axis=1)
y_train = car_train['Price'] 

X_test = car_test.drop(columns='Price', axis=1)
y_test = car_test['Price']

# %% [markdown]
# #### **Benchmark Model**

# %%
# Algoritma Yang Akan Digunakan
LR = LinearRegression()
KNN = KNeighborsRegressor()
DT = DecisionTreeRegressor(random_state=2020)
RF = RandomForestRegressor(random_state=2020)
ADA = AdaBoostRegressor(random_state=2020)
GB = GradientBoostingRegressor(random_state=2020)
XGB = XGBRegressor(random_state=2020)

log_LR = TransformedTargetRegressor(LR, func=np.log, inverse_func=np.exp)
log_KNN = TransformedTargetRegressor(KNN, func=np.log, inverse_func=np.exp)
log_DT = TransformedTargetRegressor(DT, func=np.log, inverse_func=np.exp)
log_RF = TransformedTargetRegressor(RF, func=np.log, inverse_func=np.exp)
log_ADA = TransformedTargetRegressor(ADA, func=np.log, inverse_func=np.exp)
log_GB = TransformedTargetRegressor(GB, func=np.log, inverse_func=np.exp)
log_XGB = TransformedTargetRegressor(XGB, func=np.log, inverse_func=np.exp)

# Scaling Data
scaler_data = StandardScaler()

# Kandidat Algoritma
models = [log_LR, log_KNN, log_DT, log_RF, log_ADA, log_GB, log_XGB]

score_R2 = []

score_RMSE = []
mean_RMSE = []
std_RMSE = []

score_MAE = []
mean_MAE = []
std_MAE = []

score_MAPE = []
mean_MAPE = []
std_MAPE = []

# Mencari Algoritma Terbaik Berdasarkan Nilai MAE
for i in models:
    
    crossval = KFold(n_splits=5, shuffle=True, random_state=2023)

    estimator = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler_data),
        ('model', i)
    ])

    # RMSE
    model_cv_RMSE = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_root_mean_squared_error', 
        error_score='raise'
        )


    score_RMSE.append(model_cv_RMSE.mean())
    mean_RMSE.append(model_cv_RMSE.mean())
    std_RMSE.append(model_cv_RMSE.std())

    # MAE
    model_cv_MAE = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_mean_absolute_error', 
        error_score='raise'
        )

    score_MAE.append(model_cv_MAE.mean())
    mean_MAE.append(model_cv_MAE.mean())
    std_MAE.append(model_cv_MAE.std())

    # MAPE
    model_cv_MAPE = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_mean_absolute_percentage_error', 
        error_score='raise'
        )


    score_MAPE.append(model_cv_MAPE.mean())
    mean_MAPE.append(model_cv_MAPE.mean())
    std_MAPE.append(model_cv_MAPE.std())

    # R-square
    R2_cv = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring="r2", 
        error_score='raise')
    

    score_R2.append(R2_cv.mean())

# %%
# Membuat DataFrame untuk ringkasan hasil evaluasi
best_model = pd.DataFrame({
    'Model': ['Linear Regression', 'KNN Regressor', 'DecisionTree Regressor', 'RandomForest Regressor', 'Ada Boost Regressor', 'Gradient Boosting Regressor', 'XGBoost Regressor'],
    'R-Square' : score_R2,
    'RMSE': mean_RMSE,
    'MAE': mean_MAE,
    'MAPE': mean_MAPE
})


# Mengurutkan model dari yang terbaik (berdasarkan R-Square tertinggi)
best_model_sorted = best_model.sort_values(by='R-Square', ascending=False)

# Menampilkan hasil evaluasi
best_model_sorted
# Out:
#                          Model  R-Square          RMSE           MAE      MAPE
# 5  Gradient Boosting Regressor  0.707460 -37480.571872 -20218.083067 -0.893953
# 6            XGBoost Regressor  0.697916 -37690.717493 -19870.319408 -0.921877
# 3       RandomForest Regressor  0.616502 -42708.235672 -20545.350601 -1.006741
# 1                KNN Regressor  0.544785 -46496.245250 -27300.302081 -0.992296
# 2       DecisionTree Regressor  0.441461 -51599.271596 -24948.898179 -1.157891
# 4          Ada Boost Regressor  0.114751 -65259.030696 -38656.015374 -0.772066
# 0            Linear Regression -2.394966 -84775.983683 -26485.475028 -1.864291

# %% [markdown]
# - Gradient Boosting Regressor menempati posisi terbaik dengan nilai R-Square sebesar 0.70460, RMSE sebesar -37240.517 (lebih rendah berarti lebih baik), dan MAE sebesar -20218.083. Meskipun model ini memiliki MAPE yang lebih besar dibandingkan dengan model lainnya, model ini menunjukkan performa keseluruhan terbaik berdasarkan kombinasi metrik tersebut. Artinya, Gradient Boosting Regressor adalah model yang paling sesuai untuk kasus ini.
#
# - XGBoost Regressor menempati posisi kedua dengan R-Square sebesar 0.697. Walaupun performanya sedikit lebih rendah dari Gradient Boosting, model ini tetap memberikan hasil yang cukup baik. XGBoost memiliki RMSE dan MAE yang lebih baik dibandingkan beberapa model lain, namun MAPE yang sedikit lebih tinggi menunjukkan adanya kesalahan yang lebih besar dalam prediksi pada beberapa sampel.
#
# - Random Forest Regressor berada di peringkat ketiga dengan R-Square sebesar 0.66156. Meskipun Random Forest secara keseluruhan performanya lebih rendah dibandingkan Gradient Boosting dan XGBoost, model ini masih menunjukkan performa yang layak dengan RMSE yang relatif kompetitif, meskipun MAE dan MAPE lebih tinggi dibandingkan kedua model terbaik.

# %% [markdown]
# Oleh karena itu, akan lebih baik untuk melakukan evaluasi lebih lanjut atau test set menggunakan model Gradient Boosting Regressor untuk memastikan bahwa model ini dapat memberikan performa yang baik pada data yang tidak terlihat.

# %%
# 2 Best Benchmark Models
models = {
    'Gradient Boosting Regressor': GradientBoostingRegressor(random_state=2020),
    'XGBoost Regressor': XGBRegressor(random_state=2020)
}

score_R2 = []
score_rmse = []
score_mae = []
score_mape = []

# TEST SET PREDICTION
for i in models:
    
    model = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler_data),
        ('model', models[i])
    ])

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    score_R2.append(r2_score(y_test, y_pred))
    score_rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    score_mae.append(mean_absolute_error(y_test, y_pred))
    score_mape.append(mean_absolute_percentage_error(y_test, y_pred))

score_before_tuning = pd.DataFrame({'R-Square': score_R2, 'RMSE': score_rmse, 'MAE': score_mae, 'MAPE': score_mape}, index=models.keys())
score_before_tuning
# Out:
#                              R-Square          RMSE           MAE  \
# Gradient Boosting Regressor  0.349477  60781.441286  35556.686431
# XGBoost Regressor            0.286237  63667.314613  34772.268329
#
#                                      MAPE
# Gradient Boosting Regressor  1.041633e+20
# XGBoost Regressor            1.049703e+20

# %% [markdown]
# Gradient Boosting Regressor dipilih sebagai model terbaik dalam hal R-Square, meskipun memiliki RMSE dan MAE yang sedikit lebih tinggi dibandingkan XGBoost. Oleh karena itu, Gradient Boosting bisa dipilih sebagai model utama, dengan catatan bahwa nilai MAPE yang sangat besar mengindikasikan adanya potensi outlier yang mungkin perlu ditangani lebih lanjut.

# %% [markdown]
# #### **Hyperparameter Tuning**

# %% [markdown]
# Pada tahap ini, Gradient Boosting Regressor digunakan untuk Hyperparameter Tuning guna menemukan kombinasi parameter terbaik yang meningkatkan performa model. Parameter yang diuji termasuk max_depth (kedalaman maksimum pohon), learning_rate (kecepatan pembelajaran), n_estimators (jumlah pohon), subsample (persentase data yang digunakan untuk setiap pohon), dan max_features (jumlah maksimum fitur yang digunakan di setiap split).

# %%
# Tree Depth
max_depth = list(np.arange(1, 11))

# Learning Rate
learning_rate = list(np.arange(1, 100)/100)

# Tree Estimators
n_estimators = list(np.arange(100, 201))

# Tree Rows (Persentase (%) dari total baris train set)
subsample = list(np.arange(2, 10)/10)

# Gamma (min_impurity_decrease)
gamma = list(np.arange(1, 11)) # Semakin besar nilainya, maka semakin sederhana modelnya

# Tree Features (Persentase (%) dari total kolom train set)
colsample_bytree = list(np.arange(1, 10)/10)

# Alpha (regularization)
reg_alpha = list(np.logspace(-3, 1, 10)) # Semakin besar nilainya, maka semakin sederhana modelnya


# Hyperparameter space untuk GradientBoosting tanpa colsample_bytree
hyperparam_space_gb = {
    'model__max_depth': max_depth, 
    'model__learning_rate': learning_rate,
    'model__n_estimators': n_estimators,
    'model__subsample': subsample,
    'model__max_features': list(np.arange(1, X_train.shape[1] + 1))  # Menentukan jumlah fitur yang digunakan
}

# Model Dengan Hyperparameter Tuning menggunakan GradientBoostingRegressor
GB = GradientBoostingRegressor(random_state=2020)

# Membuat Pipeline untuk GradientBoosting
estimator_gb = Pipeline([
        ('preprocessing', transformer),  # Preprocessing sesuai dengan yang sudah dilakukan
        ('scaler', scaler_data),         # Scaling data
        ('model', GB)                    # Menggunakan GradientBoostingRegressor
])

# Cross-Validation settings
crossval = KFold(n_splits=5, shuffle=True, random_state=2023)

# Hyperparameter Tuning dengan RandomizedSearchCV
random_gb = RandomizedSearchCV(
    estimator_gb, 
    param_distributions=hyperparam_space_gb,
    n_iter=50,
    cv=crossval, 
    scoring=['neg_root_mean_squared_error', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error'], 
    n_jobs=-1,
    refit='neg_root_mean_squared_error',
    random_state=2020
)

# Fitting Data Training Untuk Mencari Parameter Terbaik
random_gb.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=2023, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('One '
#                                                                                'Hot',
#                                                                                OneHotEncoder(drop='first',
#                                                                                              handle_unknown='ignore',
#                                                                                              sparse_output=False),
#                                                                                ['Region',
#                                                                                 'Gear_Type',
# ...

# %%
# Menamplikan Hasil Tuning ke Dalam Dataframe. Diurutkan Berdasarkan RMSE, MAE & MAPE
pd.DataFrame(random_gb.cv_results_).sort_values(by=['rank_test_neg_root_mean_squared_error', 'rank_test_neg_mean_absolute_error', 'rank_test_neg_mean_absolute_percentage_error']).head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 22       0.697366      0.090648         0.043641        0.005712
# 17       1.192220      0.054362         0.055801        0.014461
# 14       1.007213      0.032378         0.053378        0.004184
# 26       1.289441      0.058758         0.049441        0.003920
# 4        1.340265      0.149256         0.060596        0.016311
#
#     param_model__subsample  param_model__n_estimators  \
# 22                     0.6                        105
# 17                     0.8                        198
# 14                     0.5                        181
# 26                     0.9                        167
# 4                      0.7                        156
#
#     param_model__max_features  param_model__max_depth  \
# 22                          8                       5
# 17                          8                       5
# 14                          3                       9
# ...

# %%
# Memeriksa Nilai Skor dan Parameter Terbaik
print("\nXGBoost Regressor")
print("Best GB Score: ", random_gb.best_score_)
print("Best GB Params: ", random_gb.best_params_)
# Out:
# XGBoost Regressor
# Best GB Score:  -33924.35069555857
# Best GB Params:  {'model__subsample': 0.6, 'model__n_estimators': 105, 'model__max_features': 8, 'model__max_depth': 5, 'model__learning_rate': 0.12}

# %% [markdown]
# #### **Prediksi Test Set dengan Tuned Model**

# %%
# Model GradientBoosting
model = {'Gradient Boosting Regressor': GradientBoostingRegressor(random_state=2020)}

# Define model terhadap estimator terbaik dari hasil RandomizedSearchCV
gb_tuning = random_gb.best_estimator_

# Fitting model
gb_tuning.fit(X_train, y_train)

# Predict test set
y_pred_gb_tuning = gb_tuning.predict(X_test)

# Simpan nilai metrics R2, RMSE, MAE & MAPE setelah tuning
Rsquare_gb_tuning = r2_score(y_test, y_pred_gb_tuning)
rmse_gb_tuning = np.sqrt(mean_squared_error(y_test, y_pred_gb_tuning))
mae_gb_tuning = mean_absolute_error(y_test, y_pred_gb_tuning)
mape_gb_tuning = mean_absolute_percentage_error(y_test, y_pred_gb_tuning)

# Simpan hasil evaluasi ke DataFrame
score_after_tuning = pd.DataFrame({
    'R-Square': Rsquare_gb_tuning,
    'RMSE': rmse_gb_tuning, 
    'MAE': mae_gb_tuning, 
    'MAPE': mape_gb_tuning
}, index=model.keys())

# Tampilkan hasil evaluasi setelah tuning
score_after_tuning
# Out:
#                              R-Square          RMSE           MAE  \
# Gradient Boosting Regressor  0.336369  61390.751504  35621.988656
#
#                                      MAPE
# Gradient Boosting Regressor  1.055336e+20

# %% [markdown]
# - Gradient Boosting Regressor yang telah di-tuning masih menunjukkan performa yang kurang optimal pada test set. Meskipun tuning sudah dilakukan, model ini belum dapat memberikan prediksi yang akurat dengan kesalahan prediksi yang cukup tinggi, seperti terlihat dari RMSE dan MAE.
#
# - Nilai MAPE yang sangat besar mengindikasikan adanya masalah outlier atau distribusi data yang tidak normal, yang dapat memengaruhi hasil evaluasi model.
#
# - Perlu dilakukan analisis lebih lanjut terhadap distribusi data dan potensi outlier untuk meningkatkan performa model, serta kemungkinan melakukan tuning ulang atau menggunakan model yang berbeda.

# %% [markdown]
# #### **Performance Comparison**

# %% [markdown]
# Perbandingan performa pada model Gradient Boosting Regressor sebelum dan sesudah dilakukan proses Hyperparameter Tuning.

# %%
# Sebelum Dilakukan Proses Hyperparameter Tuning
pd.DataFrame(score_before_tuning.loc['Gradient Boosting Regressor']).T
# Out:
#                              R-Square          RMSE           MAE  \
# Gradient Boosting Regressor  0.349477  60781.441286  35556.686431
#
#                                      MAPE
# Gradient Boosting Regressor  1.041633e+20

# %%
# Setelah Dilakukan Proses Hyperparameter Tuning
score_after_tuning
# Out:
#                              R-Square          RMSE           MAE  \
# Gradient Boosting Regressor  0.336369  61390.751504  35621.988656
#
#                                      MAPE
# Gradient Boosting Regressor  1.055336e+20

# %% [markdown]
# - Proses Hyperparameter Tuning pada Gradient Boosting Regressor tidak memberikan peningkatan yang signifikan pada performa model. Sebaliknya, model mengalami sedikit penurunan pada metrik R-Square dan peningkatan pada RMSE serta MAE. Ini bisa disebabkan oleh pemilihan parameter yang tidak optimal selama proses tuning.
#
# - MAPE yang sangat tinggi di kedua kondisi menunjukkan kemungkinan adanya outlier yang perlu diatasi lebih lanjut. Mungkin perlu dilakukan data preprocessing tambahan seperti outlier removal atau scaling yang lebih efektif.

# %%
plt.figure(figsize=(14, 8))

# Scatter plot untuk Actual vs Predicted
sns.scatterplot(x=y_test, y=y_pred_gb_tuning, color="red", alpha=0.5)

# Menambahkan garis regresi untuk visualisasi prediksi
sns.regplot(x=y_test, y=y_pred_gb_tuning, scatter=False, color="blue", line_kws={"linewidth": 2})

# Memberikan title dan label
plt.title('Actual vs Prediction Price (Gradient Boosting Regressor)')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')

# Menampilkan plot

plt.show()

# %% [markdown]
# - Model Gradient Boosting Regressor ini menunjukkan hubungan yang cukup baik antara harga aktual dan prediksi, namun terdapat kesalahan yang signifikan, terutama pada harga rendah dan harga tinggi.
# - Diperlukan perbaikan lebih lanjut, seperti menangani outlier, melakukan tuning hyperparameter, atau mengumpulkan lebih banyak data di rentang harga tinggi untuk meningkatkan akurasi prediksi.

# %% [markdown]
# #### **Feature Importances**

# %%
# Mengambil fitur penting dari model GradientBoostingRegressor
gb_model = gb_tuning.named_steps['model']  # Ambil model Gradient Boosting setelah tuning

# Mengambil nama fitur dari transformer
feature_names = transformer.get_feature_names_out()

# Membuat DataFrame untuk fitur penting
feature_imp = pd.DataFrame({"Features": feature_names, "Value": gb_model.feature_importances_}).sort_values("Value", ascending=False)

# Plot bar chart untuk Top 10 Fitur yang Paling Penting
plt.figure(figsize=(12, 8))
sns.barplot(data=feature_imp.head(10), x="Value", y="Features", color="yellow")
plt.title("Top 10 Feature Importance (Gradient Boosting)", fontsize=16)
plt.xlabel("Feature Importance", fontsize=14)
plt.ylabel("Features", fontsize=14)
plt.show()

# %% [markdown]
# - Tahun pembuatan, ukuran mesin, dan jarak tempuh adalah tiga fitur utama yang paling signifikan dalam menentukan harga mobil berdasarkan hasil Gradient Boosting Regressor.
#
# - Selain itu, jenis mobil, merk mobil, dan opsi fitur juga berperan penting dalam memprediksi harga.
#
# - Hasil ini masuk akal secara bisnis, karena faktor-faktor tersebut memang sering menjadi penentu utama dalam menilai harga kendaraan di pasar.

# %% [markdown]
# ## **Conclusion & Recommendation**

# %% [markdown]
# ### **Conclusion**

# %% [markdown]
# Model Gradient Boosting Regressor dengan pemilihan fitur otomatis menunjukkan performa yang cukup baik dalam memprediksi harga mobil. Setelah melalui tahap preprocessing data dan hyperparameter tuning, model ini menggunakan fitur-fitur yang paling signifikan seperti tahun pembuatan, ukuran mesin, dan jarak tempuh untuk memaksimalkan akurasi prediksi. Meskipun terjadi sedikit penurunan performa setelah tuning dengan nilai R-Square sebesar 0.3367, model ini tetap mampu memberikan wawasan penting tentang faktor-faktor utama yang memengaruhi harga kendaraan. Dengan peningkatan lebih lanjut dalam penanganan outlier dan tuning parameter yang lebih tepat, model ini diharapkan dapat membantu perusahaan dalam meningkatkan keakuratan prediksi harga dan mengoptimalkan strategi harga kendaraan di pasar.

# %% [markdown]
# ### **Recommendation**

# %% [markdown]
# Bisnis:
#
# - Optimalisasi Harga: Berdasarkan hasil model, fitur-fitur seperti tahun pembuatan, ukuran mesin, dan jarak tempuh memiliki pengaruh besar terhadap harga kendaraan. Perusahaan dapat menggunakan informasi ini untuk mengoptimalkan harga kendaraan yang lebih kompetitif, terutama dengan mempertimbangkan kondisi kendaraan yang lebih baru dan dengan spesifikasi mesin yang lebih baik.
#
# - Strategi Pemasaran Berdasarkan Fitur Utama: Perusahaan dapat memfokuskan strategi pemasaran pada fitur-fitur yang paling penting dalam menentukan harga kendaraan. Misalnya, mempromosikan kendaraan dengan jarak tempuh rendah dan mesin bertenaga besar untuk meningkatkan minat pelanggan di segmen premium.
#
# - Pemanfaatan Prediksi untuk Strategi Harga: Marketplace dapat menggunakan hasil prediksi ini untuk memastikan harga yang ditawarkan adil dan kompetitif, meningkatkan kepercayaan antara penjual dan pembeli, serta mengoptimalkan transaksi.
#
# Segmentasi Pelanggan Berdasarkan Rentang Harga: Karena model masih mengalami kesulitan dalam memprediksi rentang harga yang sangat tinggi dan rendah, perusahaan bisa menggunakan hasil analisis ini untuk merancang strategi khusus untuk setiap segmen harga, baik untuk kendaraan dengan harga terjangkau maupun kendaraan mewah.
#
#
# Modeling:
#
# - Penanganan Outlier: Nilai MAPE yang sangat tinggi mengindikasikan adanya outlier atau data dengan distribusi yang tidak normal. Disarankan untuk melakukan pembersihan data lebih lanjut atau menerapkan metode penanganan outlier yang lebih baik agar prediksi lebih akurat.
#
# - Tuning Hyperparameter Lebih Lanjut: Proses tuning yang dilakukan pada model Gradient Boosting Regressor belum memberikan peningkatan signifikan. Disarankan untuk menggunakan metode tuning lain seperti GridSearchCV atau mencoba range parameter yang lebih luas untuk meningkatkan performa model.
#
# - Eksperimen dengan Model Lain: Meskipun Gradient Boosting telah digunakan, disarankan untuk mencoba model alternatif seperti XGBoost atau Random Forest yang memiliki performa kompetitif dan bisa memberikan hasil yang lebih baik pada data regresi.
#
# - Penerapan Feature Engineering: Menambahkan fitur-fitur baru yang relevan, seperti riwayat perbaikan atau status kepemilikan kendaraan, dapat membantu meningkatkan akurasi prediksi dan menangkap aspek-aspek yang belum diperhitungkan dalam model saat ini.

# %% [markdown]
# ## **Save Model**

# %%
# Pipeline untuk model Gradient Boosting
estimator = Pipeline([('preprocess', transformer), ('model', GradientBoostingRegressor(random_state=2020))])

# Fitting model
estimator.fit(X_train, y_train)

# Menyimpan model ke file menggunakan pickle
filename = 'Model_GradientBoostingRegressor_Pickle.sav'
pickle.dump(estimator, open(filename, 'wb'))

# %%
# Memuat model yang sudah disimpan
loaded_model = pickle.load(open('Model_GradientBoostingRegressor_Pickle.sav', 'rb'))

# Menggunakan model yang sudah diload untuk prediksi
y_pred_loaded = loaded_model.predict(X_test)
